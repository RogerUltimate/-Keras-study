# %% [markdown]
# <a href="https://colab.research.google.com/github/RogerUltimate/-Keras-study/blob/main/transfer_learning%EC%9D%98_%EC%A3%BC%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transfer learning & fine-tuning
#
# 전이학습(사전 학습된 모델 사용) & 미세 조정
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2020/04/15<br>
# **Last modified:** 2020/05/12<br>
# **Description:** Complete guide to transfer learning & fine-tuning in Keras.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Introduction
#
# **Transfer learning** consists of taking features learned on one problem, and
# leveraging them on a new, similar problem. For instance, features from a model that has
# learned to identify racoons may be useful to kick-start a model meant to identify
#  tanukis.
#
# Transfer learning is usually done for tasks where your dataset has too little data to
#  train a full-scale model from scratch.
#
# 전이학습은 모델을 처음부터 훈련시키기에는 데이터셋이 너무 작을 때 사용
#
# The most common incarnation of transfer learning in the context of deep learning is the
#  following workflow:
#
# 1. Take layers from a previously trained model.
# 2. Freeze them, so as to avoid destroying any of the information they contain during
#  future training rounds.
# 3. Add some new, trainable layers on top of the frozen layers. They will learn to turn
#  the old features into predictions on a  new dataset.
# 4. Train the new layers on your dataset.
#
# A last, optional step, is **fine-tuning**, which consists of unfreezing the entire
# model you obtained above (or part of it), and re-training it on the new data with a
# very low learning rate. This can potentially achieve meaningful improvements, by
#  incrementally adapting the pretrained features to the new data.
#
# 미세 조정은 아주 낮은 학습률을 사용함
#
# First, we will go over the Keras `trainable` API in detail, which underlies most
#  transfer learning & fine-tuning workflows.
#
# Then, we'll demonstrate the typical workflow by taking a model pretrained on the
# ImageNet dataset, and retraining it on the Kaggle "cats vs dogs" classification
#  dataset.
#
# This is adapted from
# [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python)
#  and the 2016 blog post
# ["building powerful image classification models using very little
#  data"](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html).

# %% [markdown]
# ## Freezing layers: understanding the `trainable` attribute
#
# Layers & models have three weight attributes:
#
# - `weights` is the list of all weights variables of the layer.
# - `trainable_weights` is the list of those that are meant to be updated (via gradient
#  descent) to minimize the loss during training.
#
# trainable_weights는 학습과정에서 손실을 최소화하기 위해(경사하강법을 이용하여) update되는 가중치
#
# - `non_trainable_weights` is the list of those that aren't meant to be trained.
#  Typically they are updated by the model during the forward pass.
#
# non_trainable_weights는 학습되지 않는 가중치들로서, forward pass 시에 모델에 의해 update됨
#
# **Example: the `Dense` layer has 2 trainable weights (kernel & bias)**
#
# 예. Dense 레이어는 2개의 trainable weights를 가짐: kernel & bias
#
# Y = Wx + b에서 W와 b를 의미함

# %%
layer = keras.layers.Dense(3)
layer.build((None, 4))  # Create the weights

print("weights:", len(layer.weights))
print("trainable_weights:", len(layer.trainable_weights))
print("non_trainable_weights:", len(layer.non_trainable_weights))

# %% [markdown]
# In general, all weights are trainable weights. The only built-in layer that has
# non-trainable weights is the `BatchNormalization` layer. It uses non-trainable weights
#  to keep track of the mean and variance of its inputs during training.
# To learn how to use non-trainable weights in your own custom layers, see the
# [guide to writing new layers from scratch](https://keras.io/guides/making_new_layers_and_models_via_subclassing/).
#
# **Example: the `BatchNormalization` layer has 2 trainable weights and 2 non-trainable
#  weights**
#
# 일반적으로 모든 weights는 trainable weights임. built-in 레이어로서 유일하게 non-trainable weights를 갖는 것은 BatchNormalization 레이어임. BatchNormalization 레이어는 non-trainable weights를 사용하여 입력값의 평균과 분산을 학습과정 내내 추적함.
# 예. BatchNormalization 레이어는 trainable weights 2개와 non-trainable weights 2개를 갖는다

# %%
layer = keras.layers.BatchNormalization()
layer.build((None, 4))  # Create the weights

print("weights:", len(layer.weights))
print("trainable_weights:", len(layer.trainable_weights))
print("non_trainable_weights:", len(layer.non_trainable_weights))

# %% [markdown]
# Layers & models also feature a boolean attribute `trainable`. Its value can be changed.
# Setting `layer.trainable` to `False` moves all the layer's weights from trainable to
# non-trainable.  This is called "freezing" the layer: the state of a frozen layer won't
# be updated during training (either when training with `fit()` or when training with
#  any custom loop that relies on `trainable_weights` to apply gradient updates).
#
# **Example: setting `trainable` to `False`**

# %%
layer = keras.layers.Dense(3)
layer.build((None, 4))  # Create the weights
layer.trainable = False  # Freeze the layer

print("weights:", len(layer.weights))
print("trainable_weights:", len(layer.trainable_weights))
print("non_trainable_weights:", len(layer.non_trainable_weights))

# %% [markdown]
# When a trainable weight becomes non-trainable, its value is no longer updated during
#  training.

# %%
# Dense 레이어를 2개 만들고, 첫번째 레이어를 동결시킨 뒤 그 weights를 저장하고,
# 레이어를 학습시킨 뒤, 첫번째 레이어의 weights를 꺼내어 기존의 저장해 둔 weights와 비교(동일함)

# Make a model with 2 layers
layer1 = keras.layers.Dense(3, activation="relu")
layer2 = keras.layers.Dense(3, activation="sigmoid")
model = keras.Sequential([keras.Input(shape=(3,)), layer1, layer2])

# Freeze the first layer
layer1.trainable = False

# Keep a copy of the weights of layer1 for later reference
initial_layer1_weights_values = layer1.get_weights()

# Train the model
model.compile(optimizer="adam", loss="mse")
model.fit(np.random.random((2, 3)), np.random.random((2, 3)))

# Check that the weights of layer1 have not changed during training
final_layer1_weights_values = layer1.get_weights()
np.testing.assert_allclose(              # 두 객체가 동일하지 않으면 에러를 발생시키는 함수
    initial_layer1_weights_values[0], final_layer1_weights_values[0]
)
np.testing.assert_allclose(
    initial_layer1_weights_values[1], final_layer1_weights_values[1]
)

# %% [markdown]
# Do not confuse the `layer.trainable` attribute with the argument `training` in
# `layer.__call__()` (which controls whether the layer should run its forward pass in
#  inference mode or training mode). For more information, see the
# [Keras FAQ](
#   https://keras.io/getting_started/faq/#whats-the-difference-between-the-training-argument-in-call-and-the-trainable-attribute).

# %% [markdown]
# ## Recursive setting of the `trainable` attribute
#
# If you set `trainable = False` on a model or on any layer that has sublayers,
# all children layers become non-trainable as well.
#
# 상위 레이어를 동결시키면 하위 레이어도 따라서 동결됨.
#
# 아래 코드는 그 예
#
# **Example:**

# %%
inner_model = keras.Sequential(
    [
        keras.Input(shape=(3,)),
        keras.layers.Dense(3, activation="relu"),
        keras.layers.Dense(3, activation="relu"),
    ]
)

model = keras.Sequential(
    [keras.Input(shape=(3,)), inner_model, keras.layers.Dense(3, activation="sigmoid"),]
)

model.trainable = False  # Freeze the outer model

assert inner_model.trainable == False  # All layers in `model` are now frozen
assert inner_model.layers[0].trainable == False  # `trainable` is propagated recursively

# %% [markdown]
# ## The typical transfer-learning workflow
#
# This leads us to how a typical transfer learning workflow can be implemented in Keras:
#
# 사전 학습된 레이어는 trainable=False로 동결하고, 그 위에 분류기(Dense) 레이어를 쌓아서 새로운 데이터셋으로 학습시키는 방법
# 1. Instantiate a base model and load pre-trained weights into it.
# 2. Freeze all layers in the base model by setting `trainable = False`.
# 3. Create a new model on top of the output of one (or several) layers from the base
#  model.
# 4. Train your new model on your new dataset.
#
# 보다 간단한 방법은: 사전 학습된 레이어에 새로운 데이터셋을 입력시켜서 결과물을 추출('특성 추출'이라 부름)하고 그 결과물을 분류기(Dense) 모델의 입력으로 사용
#
# Note that an alternative, more lightweight workflow could also be:
#
# 1. Instantiate a base model and load pre-trained weights into it.
# 2. Run your new dataset through it and record the output of one (or several) layers
#  from the base model. This is called **feature extraction**.
# 3. Use that output as input data for a new, smaller model.
#
# A key advantage of that second workflow is that you only run the base model once on
#  your data, rather than once per epoch of training. So it's a lot faster & cheaper.
#
# 두번째 방법의 장점은 base model(사전학습된 모델)을 한번만 실행시키면 된다는 것. 즉 학습 시 매 에펔마다 실행할 필요가 없다는 것
#
# An issue with that second workflow, though, is that it doesn't allow you to dynamically
# modify the input data of your new model during training, which is required when doing
# data augmentation, for instance. Transfer learning is typically used for tasks when
# your new dataset has too little data to train a full-scale model from scratch, and in
# such scenarios data augmentation is very important. So in what follows, we will focus
#  on the first workflow.
#
# 하지만 두번째 방법은 학습 도중에 입력 데이터를 동적으로 변경할 수 없으며, 이는 data augmentation을 할 수 없음을 의미. 따라서 이하에서는 첫째 방법을 설명함
#
# Here's what the first workflow looks like in Keras:
#
# 첫번째 방법의 작업흐름은 다음과 같음
#
# First, instantiate a base model with pre-trained weights.
#
# 첫째, 사전 학습된 weights를 불러와서 base model을 시작함
#
# ```python
# base_model = keras.applications.Xception(
#     weights='imagenet',  # Load weights pre-trained on ImageNet.
#     input_shape=(150, 150, 3),
#     include_top=False)  # Do not include the ImageNet classifier at the top.
# ```
#
# Then, freeze the base model.
#
# 다음, base model을 동결함
#
# ```python
# base_model.trainable = False
# ```
#
# Create a new model on top.
#
# 그 위에 새로운 모델을 만듬
#
# ```python
# inputs = keras.Input(shape=(150, 150, 3))
# # We make sure that the base_model is running in inference mode here,
# # by passing `training=False`. This is important for fine-tuning, as you will
# # learn in a few paragraphs.
# x = base_model(inputs, training=False)
# # Convert features of shape `base_model.output_shape[1:]` to vectors
# x = keras.layers.GlobalAveragePooling2D()(x)
# # A Dense classifier with a single unit (binary classification)
# outputs = keras.layers.Dense(1)(x)
# model = keras.Model(inputs, outputs)
# ```
#
# Train the model on new data.
#
# 모델을 새로운 데이터로 학습시킴
#
# ```python
# model.compile(optimizer=keras.optimizers.Adam(),
#               loss=keras.losses.BinaryCrossentropy(from_logits=True),
#               metrics=[keras.metrics.BinaryAccuracy()])
# model.fit(new_dataset, epochs=20, callbacks=..., validation_data=...)
# ```

# %% [markdown]
# ## Fine-tuning 미세 조정
#
# Once your model has converged on the new data, you can try to unfreeze all or part of
#  the base model and retrain the whole model end-to-end with a very low learning rate.
#
# 앞에서 설명한 방식으로 학습이 이루어진 이후에, base model의 모든 레이어를 동결해제하고, 전체 모델의 처음부터 끝까지를 아주 낮은 학습률로 재학습시킬 수 있음
#
# This is an optional last step that can potentially give you incremental improvements.
#  It could also potentially lead to quick overfitting -- keep that in mind.
#
# It is critical to only do this step *after* the model with frozen layers has been
# trained to convergence. If you mix randomly-initialized trainable layers with
# trainable layers that hold pre-trained features, the randomly-initialized layers will
# cause very large gradient updates during training, which will destroy your pre-trained
#  features.
#
# 동결된 레이어를 가진 모델이 학습되어 converge한 이후에만 이 미세 조정을 실행하여야 한다. 그렇게 하지 않고, **랜덤하게 초기화된 trainable 레이어들**과 사전 학습된 특성(features)들을 지니고 있는 trainable 레이어들을 섞어버리면, **랜덤하게 초기화된 레이어들**로 인하여 학습 도중에 매우 큰 gradient 갱신이 일어나서, 사전 학습된 features들이 망가질 것이다 (학습 초기의 gradient 갱신 폭은 크다. due to momentum?)
#
# It's also critical to use a very low learning rate at this stage, because
# you are training a much larger model than in the first round of training, on a dataset
#  that is typically very small.
# As a result, you are at risk of overfitting very quickly if you apply large weight
#  updates. Here, you only want to readapt the pretrained weights in an incremental way.
#
# 아주 낮은 학습률을 사용해야 한다. 매우 큰 모델로 (보통의 경우에) 아주 작은 데이터셋을 학습시키기 때문에, 커다란 weight 갱신을 사용한다면, 상당히 빠르게 오버피팅될 위험이 있다.
#
# This is how to implement fine-tuning of the whole base model:
#
# ```python
# # Unfreeze the base model
# base_model.trainable = True
#
# # It's important to recompile your model after you make any changes
# # to the `trainable` attribute of any inner layer, so that your changes
# # are take into account
#
# 레이어의 trainable 속성을 변경하면 compile을 다시 해야만 변경이 반영된다. 참고로 compile을 하는 순간 그 모델의 행동은 동결되기 때문이다
#
# model.compile(optimizer=keras.optimizers.Adam(1e-5),  # Very low learning rate
#               loss=keras.losses.BinaryCrossentropy(from_logits=True),
#               metrics=[keras.metrics.BinaryAccuracy()])
#
# # Train end-to-end. Be careful to stop before you overfit!
# model.fit(new_dataset, epochs=10, callbacks=..., validation_data=...)
# ```
#
# **Important note about `compile()` and `trainable`**
#
# Calling `compile()` on a model is meant to "freeze" the behavior of that model. This
#  implies that the `trainable`
# attribute values at the time the model is compiled should be preserved throughout the
#  lifetime of that model,
# until `compile` is called again. Hence, if you change any `trainable` value, make sure
#  to call `compile()` again on your
# model for your changes to be taken into account.
#
# **Important notes about `BatchNormalization` layer**
#
# Many image models contain `BatchNormalization` layers. That layer is a special case on
#  every imaginable count. Here are a few things to keep in mind.
#
# - `BatchNormalization` contains 2 non-trainable weights that get updated during
# training. These are the variables tracking the mean and variance of the inputs.
# - When you set `bn_layer.trainable = False`, the `BatchNormalization` layer will
# run in inference mode, and will not update its mean & variance statistics. This is not
# the case for other layers in general, as
# [weight trainability & inference/training modes are two orthogonal concepts](
#   https://keras.io/getting_started/faq/#whats-the-difference-between-the-training-argument-in-call-and-the-trainable-attribute).
# But the two are tied in the case of the `BatchNormalization` layer.
# - When you unfreeze a model that contains `BatchNormalization` layers in order to do
# fine-tuning, you should keep the `BatchNormalization` layers in inference mode by
#  passing `training=False` when calling the base model.
# Otherwise the updates applied to the non-trainable weights will suddenly destroy
# what the model has learned.
#
# BatchNormalization 레이어는 2개의 non-trainable weights를 갖고 있다. 이들은 학습 시에 갱신된다. 이들은 입력값의 평균과 분산을 추적하는 변수들이다. 모델을 동결 해제하더라도 BatchNormalization 레이어는 training=False로 설정해 주어야 기존에 학습된 내용이 망가지지 않는다.
#
# You'll see this pattern in action in the end-to-end example at the end of this guide.

# %% [markdown]
# ## Transfer learning & fine-tuning with a custom training loop
#
# If instead of `fit()`, you are using your own low-level training loop, the workflow
# stays essentially the same. You should be careful to only take into account the list
#  `model.trainable_weights` when applying gradient updates:
#
# fit() 대신에 당신 스스로 만든 저수준의 학습 loop를 사용하고 있는 경우에도, 작업 순서는 기본적으로 동일하다. Gradient를 갱신할 때 model.trainable_weight 리스트만을 고려해야 한다. (fit() 과정에 대한 이해는 교재 p.79~ 2.4절 참조)
#
# ```python
# # Create base model
# base_model = keras.applications.Xception(
#     weights='imagenet',
#     input_shape=(150, 150, 3),
#     include_top=False)
# # Freeze base model
# base_model.trainable = False  ###
#
# # Create new model on top.
# inputs = keras.Input(shape=(150, 150, 3))
# x = base_model(inputs, training=False)
# x = keras.layers.GlobalAveragePooling2D()(x)
# outputs = keras.layers.Dense(1)(x)
# model = keras.Model(inputs, outputs)
#
# loss_fn = keras.losses.BinaryCrossentropy(from_logits=True)
# optimizer = keras.optimizers.Adam()
#
# # Iterate over the batches of a dataset.
# for inputs, targets in new_dataset:
#     # Open a GradientTape.
#     with tf.GradientTape() as tape:
#         # Forward pass.
#         predictions = model(inputs)
#         # Compute the loss value for this batch.
#         loss_value = loss_fn(targets, predictions)
#
#     # Get gradients of loss wrt the *trainable* weights.
#     gradients = tape.gradient(loss_value, model.trainable_weights)   ###
#     # Update the weights of the model.
#     optimizer.apply_gradients(zip(gradients, model.trainable_weights))   ###
# ```

# %% [markdown]
# Likewise for fine-tuning.

# %% [markdown]
# ## An end-to-end example: fine-tuning an image classification model on a cats vs. dogs dataset
#
# To solidify these concepts, let's walk you through a concrete end-to-end transfer
# learning & fine-tuning example. We will load the Xception model, pre-trained on
#  ImageNet, and use it on the Kaggle "cats vs. dogs" classification dataset.
#
#  이미지넷 데이터셋으로 사전 학습된 Xception 모델을 가져다가 캐글의 cats vs. dogs 분류 데이터셋에 사용하겠음

# %% [markdown]
# ### Getting the data
#
# First, let's fetch the cats vs. dogs dataset using TFDS. If you have your own dataset,
# you'll probably want to use the utility
# `tf.keras.preprocessing.image_dataset_from_directory` to generate similar labeled
#  dataset objects from a set of images on disk filed into class-specific folders.
#
# Transfer learning is most useful when working with very small datasets. To keep our
# dataset small, we will use 40% of the original training data (25,000 images) for
#  training, 10% for validation, and 10% for testing.
#
# 전이학습은 아주 작은 데이터셋으로 작업할 때 매우 유용하기 때문에, 우리의 데이터셋을 작게 하기 위하여, 원본 학습 데이터(이미지 25,000개)의 40%를 학습에 사용하고, 10%를 검증에, 10%를 테스트에 사용하겠음

# %%
import tensorflow_datasets as tfds

tfds.disable_progress_bar()

train_ds, validation_ds, test_ds = tfds.load(
    "cats_vs_dogs",
    # Reserve 10% for validation and 10% for test
    split=["train[:40%]", "train[40%:50%]", "train[50%:60%]"],
    as_supervised=True,  # Include labels    지도 학습 = 레이블이 필요
)

# %%
import tensorflow as tf

# cardinality: 집합의 원소 --> Dataset의 len()을 보는 메소드
print("Number of training samples: %d" % tf.data.experimental.cardinality(train_ds))
print(
    "Number of validation samples: %d" % tf.data.experimental.cardinality(validation_ds)
)
print("Number of test samples: %d" % tf.data.experimental.cardinality(test_ds))
# Out:
# Number of training samples: 9305
# Number of validation samples: 2326
# Number of test samples: 2326

# %% [markdown]
# These are the first 9 images in the training dataset -- as you can see, they're all
#  different sizes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
# 아래를 보면 Dataset이 이미지와 레이블로 구성되어 있음을 알 수 있음
for i, (image, label) in enumerate(train_ds.take(9)):   
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image)
    plt.title(int(label))
    plt.axis("off")

# %% [markdown]
# We can also see that label 1 is "dog" and label 0 is "cat".

# %% [markdown]
# ### Standardizing the data
#
# Our raw images have a variety of sizes. In addition, each pixel consists of 3 integer
# values between 0 and 255 (RGB level values). This isn't a great fit for feeding a
#  neural network. We need to do 2 things:
#
# - Standardize to a fixed image size. We pick 150x150.
#
#   특정 이미지 크기로 표준화하겠음. 여기서는 150x150으로 하겠음
# - Normalize pixel values between -1 and 1. We'll do this using a `Normalization` layer as
#  part of the model itself.
#
#   픽셀의 값을 -1과 1 사이로 정규화하겠음. 이 작업은 모델의 일부로 Normalization 레이어를 써서 하겠음
#
# In general, it's a good practice to develop models that take raw data as input, as
# opposed to models that take already-preprocessed data. The reason being that, if your
# model expects preprocessed data, any time you export your model to use it elsewhere
# (in a web browser, in a mobile app), you'll need to reimplement the exact same
# preprocessing pipeline. This gets very tricky very quickly. So we should do the least
#  possible amount of preprocessing before hitting the model.
#
# Here, we'll do image resizing in the data pipeline (because a deep neural network can
# only process contiguous batches of data), and we'll do the input value scaling as part
#  of the model, when we create it.
#
# Let's resize images to 150x150:

# %%
size = (150, 150)

train_ds = train_ds.map(lambda x, y: (tf.image.resize(x, size), y))
validation_ds = validation_ds.map(lambda x, y: (tf.image.resize(x, size), y))
test_ds = test_ds.map(lambda x, y: (tf.image.resize(x, size), y))

# %%
print(train_ds.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-4fd1780d5089> in <module>()
# ----> 1 print(train_ds.shape)
#
# AttributeError: 'MapDataset' object has no attribute 'shape'

# %% [markdown]
# Besides, let's batch the data and use caching & prefetching to optimize loading speed.
#
# loading 속도를 최적화하기 위하여 데이터를 batch 하고, caching과 prefetching을 사용함

# %%
batch_size = 32

train_ds = train_ds.cache().batch(batch_size).prefetch(buffer_size=10)
validation_ds = validation_ds.cache().batch(batch_size).prefetch(buffer_size=10)
test_ds = test_ds.cache().batch(batch_size).prefetch(buffer_size=10)

# %% [markdown]
# ### Using random data augmentation
#
# When you don't have a large image dataset, it's a good practice to artificially
#  introduce sample diversity by applying random yet realistic transformations to
# the training images, such as random horizontal flipping or small random rotations. This
# helps expose the model to different aspects of the training data while slowing down
#  overfitting.
#
# 랜덤 데이터 증식을 사용함으로써 모델이 학습 데이터의 다양한 측면에 대해 학습하게 하고, 오버피팅을 늦춤

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
    ]
)

# %% [markdown]
# Let's visualize what the first image of the first batch looks like after various random
#  transformations:

# %%
import numpy as np

for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    first_image = images[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(
            tf.expand_dims(first_image, 0), training=True
        )
        plt.imshow(augmented_image[0].numpy().astype("int32"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %% [markdown]
# ## Build a model
#
# Now let's built a model that follows the blueprint we've explained earlier.
#
# Note that:
#
# - We add a `Normalization` layer to scale input values (initially in the `[0, 255]`
#  range) to the `[-1, 1]` range.
# - We add a `Dropout` layer before the classification layer, for regularization.
# - We make sure to pass `training=False` when calling the base model, so that
# it runs in inference mode, so that batchnorm statistics don't get updated
# even after we unfreeze the base model for fine-tuning.
#
# 다음 사항들에 유의:
#
# - Normalization 레이어를 사용하여 입력값을 [0, 255] --> [-1, 1] 범위 조정
# - 분류기 전에 regularization을 위해 Dropout 레이어를 추가함
# - base model을 불러올 때 training=False로 하여 불러옴 --> 추론 모드로 실행되어 batchnorm의 통계값들이 갱신되지 않게 함; base model을 동결 해제하여 미세 조정을 할 때에도

# %%
base_model = keras.applications.Xception(
    weights="imagenet",  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False,
)  # Do not include the ImageNet classifier at the top.

# Freeze the base_model
base_model.trainable = False

# Create new model on top
inputs = keras.Input(shape=(150, 150, 3))
x = data_augmentation(inputs)  # Apply random data augmentation

# Pre-trained Xception weights requires that input be normalized
# from (0, 255) to a range (-1., +1.), the normalization layer
# does the following, outputs = (inputs - mean) / sqrt(var)
# 사전 학습된 Xception 가중치에 맞추려면 입력값이 (0, 255)가 아닌 (-1., +1.) 범위로
# 정규화되어야 한다. normalization 레이어는 다음과 같은 것을 한다: 출력값 = (입력값 - 평균) / 루트(분산)
norm_layer = keras.layers.experimental.preprocessing.Normalization()
mean = np.array([127.5] * 3)   # --> [127.5 127.5 127.5]
var = mean ** 2                # --> [127.5**2 127.5**2 127.5**2]
# Scale inputs to [-1, +1]
x = norm_layer(x)
norm_layer.set_weights([mean, var])   # 정규화 레이어의 가중치들을 mean, var로 설정함??????????????????

# The base model contains batchnorm layers. We want to keep them in inference mode
# when we unfreeze the base model for fine-tuning, so we make sure that the
# base_model is running in inference mode here.
# base model 안에 batchnorm 레이어들이 있다. 미세 조정을 위하여 base model을 동결 해제할
# 때에도 batchnorm 레이어들은 추론 모드로 유지되게 하기 위해서, 여기서는 base model 자체를
# 추론 모드로 실행시킨다
x = base_model(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = keras.layers.Dense(1)(x)
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 3s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 150, 150, 3)       0
# _________________________________________________________________
# normalization (Normalization (None, 150, 150, 3)       7
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 20,863,536
# Trainable params: 2,049
# Non-trainable params: 20,861,487
# _________________________________________________________________

# %% [markdown]
# ## Train the top layer

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

epochs = 20
model.fit(train_ds, epochs=epochs, validation_data=validation_ds)
# Out:
# Epoch 1/20
# 291/291 [==============================] - 35s 62ms/step - loss: 0.1592 - binary_accuracy: 0.9333 - val_loss: 0.0808 - val_binary_accuracy: 0.9678
# Epoch 2/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.1209 - binary_accuracy: 0.9496 - val_loss: 0.0767 - val_binary_accuracy: 0.9725
# Epoch 3/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.1081 - binary_accuracy: 0.9520 - val_loss: 0.0745 - val_binary_accuracy: 0.9695
# Epoch 4/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.1074 - binary_accuracy: 0.9568 - val_loss: 0.0785 - val_binary_accuracy: 0.9690
# Epoch 5/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.1030 - binary_accuracy: 0.9564 - val_loss: 0.0741 - val_binary_accuracy: 0.9716
# Epoch 6/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.1006 - binary_accuracy: 0.9581 - val_loss: 0.0719 - val_binary_accuracy: 0.9690
# Epoch 7/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0964 - binary_accuracy: 0.9613 - val_loss: 0.0721 - val_binary_accuracy: 0.9695
# Epoch 8/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0984 - binary_accuracy: 0.9600 - val_loss: 0.0737 - val_binary_accuracy: 0.9699
# Epoch 9/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0921 - binary_accuracy: 0.9622 - val_loss: 0.0713 - val_binary_accuracy: 0.9712
# Epoch 10/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0982 - binary_accuracy: 0.9614 - val_loss: 0.0707 - val_binary_accuracy: 0.9725
# Epoch 11/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0957 - binary_accuracy: 0.9613 - val_loss: 0.0701 - val_binary_accuracy: 0.9733
# Epoch 12/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0943 - binary_accuracy: 0.9617 - val_loss: 0.0709 - val_binary_accuracy: 0.9716
# Epoch 13/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0908 - binary_accuracy: 0.9617 - val_loss: 0.0708 - val_binary_accuracy: 0.9733
# Epoch 14/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0953 - binary_accuracy: 0.9632 - val_loss: 0.0718 - val_binary_accuracy: 0.9725
# Epoch 15/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0922 - binary_accuracy: 0.9623 - val_loss: 0.0769 - val_binary_accuracy: 0.9712
# Epoch 16/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0903 - binary_accuracy: 0.9620 - val_loss: 0.0738 - val_binary_accuracy: 0.9733
# Epoch 17/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0885 - binary_accuracy: 0.9642 - val_loss: 0.0721 - val_binary_accuracy: 0.9721
# Epoch 18/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0896 - binary_accuracy: 0.9632 - val_loss: 0.0719 - val_binary_accuracy: 0.9729
# Epoch 19/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0939 - binary_accuracy: 0.9615 - val_loss: 0.0714 - val_binary_accuracy: 0.9721
# Epoch 20/20
# 291/291 [==============================] - 16s 55ms/step - loss: 0.0913 - binary_accuracy: 0.9628 - val_loss: 0.0711 - val_binary_accuracy: 0.9725

# %% [markdown]
# ## Do a round of fine-tuning of the entire model
#
# Finally, let's unfreeze the base model and train the entire model end-to-end with a low
#  learning rate.
#
# Importantly, although the base model becomes trainable, it is still running in
# inference mode since we passed `training=False` when calling it when we built the
# model. This means that the batch normalization layers inside won't update their batch
# statistics. If they did, they would wreck havoc on the representations learned by the
#  model so far.
#
# 마지막으로 base model을 동결 해제하고, 전체 모델을 처음부터 끝까지 낮은 학습률로 학습시킨다. base model이 학습 가능하게 되지만, base model을 불러올 때 training=False로 불러왔기 때문에 base model은 아직도 추론 모드로 실행되고 있다. 이는 그 안에 들어 있는 batch normalization 레이어들이 보유한 통계 수치들이 갱신되지 않는다는 의미이다

# %%
# Unfreeze the base_model. Note that it keeps running in inference mode
# since we passed `training=False` when calling it. This means that
# the batchnorm layers will not update their batch statistics.
# This prevents the batchnorm layers from undoing all the training
# we've done so far.
base_model.trainable = True
model.summary()

model.compile(
    optimizer=keras.optimizers.Adam(1e-5),  # Low learning rate
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

epochs = 10
model.fit(train_ds, epochs=epochs, validation_data=validation_ds)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 150, 150, 3)       0
# _________________________________________________________________
# normalization (Normalization (None, 150, 150, 3)       7
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 20,863,536
# Trainable params: 20,809,001
# Non-trainable params: 54,535
# _________________________________________________________________
# Epoch 1/10
# 291/291 [==============================] - 71s 222ms/step - loss: 0.0729 - binary_accuracy: 0.9702 - val_loss: 0.0515 - val_binary_accuracy: 0.9794
# Epoch 2/10
# 291/291 [==============================] - 64s 220ms/step - loss: 0.0548 - binary_accuracy: 0.9774 - val_loss: 0.0529 - val_binary_accuracy: 0.9794
# Epoch 3/10
# 291/291 [==============================] - 64s 221ms/step - loss: 0.0473 - binary_accuracy: 0.9818 - val_loss: 0.0438 - val_binary_accuracy: 0.9824
# Epoch 4/10
# 291/291 [==============================] - 64s 220ms/step - loss: 0.0384 - binary_accuracy: 0.9850 - val_loss: 0.0500 - val_binary_accuracy: 0.9811
# Epoch 5/10
# 291/291 [==============================] - 64s 220ms/step - loss: 0.0272 - binary_accuracy: 0.9890 - val_loss: 0.0506 - val_binary_accuracy: 0.9828
# Epoch 6/10
# 291/291 [==============================] - 64s 220ms/step - loss: 0.0253 - binary_accuracy: 0.9910 - val_loss: 0.0511 - val_binary_accuracy: 0.9811
# Epoch 7/10
# 291/291 [==============================] - 64s 220ms/step - loss: 0.0187 - binary_accuracy: 0.9938 - val_loss: 0.0526 - val_binary_accuracy: 0.9807
# Epoch 8/10
# 291/291 [==============================] - 64s 221ms/step - loss: 0.0136 - binary_accuracy: 0.9945 - val_loss: 0.0667 - val_binary_accuracy: 0.9794
# Epoch 9/10
# 291/291 [==============================] - 64s 219ms/step - loss: 0.0113 - binary_accuracy: 0.9961 - val_loss: 0.0678 - val_binary_accuracy: 0.9807
# Epoch 10/10
# 291/291 [==============================] - 64s 220ms/step - loss: 0.0126 - binary_accuracy: 0.9954 - val_loss: 0.0656 - val_binary_accuracy: 0.9798

# %% [markdown]
# After 10 epochs, fine-tuning gains us a nice improvement here.
