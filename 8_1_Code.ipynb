# %% [markdown]
# <a href="https://colab.research.google.com/github/RogerUltimate/-Keras-study/blob/main/8_1_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://keras.io/examples/generative/lstm_character_level_text_generation/

# %%
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import random
import io
keras.__version__
# Out:
# '2.5.0'

# %%
path = keras.utils.get_file(
    "nietzsche.txt", origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt"
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893

# %%
chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40  # 40개의 단어로 된 시퀸스를 추출
step = 3  # 세 글자씩 건너뛰면서 새로운 시퀸스 샘플링
sentences = [] # 추출한 시퀸스를 담을 list
next_chars = [] # 타겟(시퀸스 다음 글자)을 담을 list
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

# 벡터화 # 원핫인코딩 > 0,1 의 이진배열로 변경
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool) 
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Total chars: 56
# Number of sequences: 200285

# %%
# 다음 글자 예측을 위한 단일 LSTM 모델
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.

# %%
type(text)
# Out:
# str

# %% [markdown]
# 1. 지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2. 특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3. 가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4.새로운 글자를 생성된 텍스트의 끝에 추가합니다.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1) 
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]: # 책의 temperature
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen] # 무작위로 텍스트를 선택
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars))) # 지금까지 생성된 글자를원핫인코딩으로 변경
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0

            preds = model.predict(x_pred, verbose=0)[0] # 다음 글자를 샘플링
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print()
# Out:
# 1565/1565 [==============================] - 192s 121ms/step - loss: 1.8995
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: " citadel, one thing is then certain: he "
# ...Generated:  which the would be the sension of the strives and the period and the stronger of the strives and the would a man and the sention of the would be the possibition of the most stranger of the pather and the sension of the soul as the hight and the hist the strong have conscience the sension of the stronger and instance of the striver and the pain the sension of the sension of the sention of the striv
#
# ...Diversity: 0.5
# ...Generating with seed: " citadel, one thing is then certain: he "
# ...Generated:  is his all their great in its such a there is it is really and their are to their not the suble be of be the extreal periaded than the and the forms and in the feelingly to not its extally to presence in the would "
#
# ...Diversity: 1.0
# ...Generating with seed: " citadel, one thing is then certain: he "
# ...Generated:  are still nature hecient for this, no for the psysuexious requar of rirmonce phulosophication of is pernadion of their upon its nom there of thisedumpless one its ro firsseno"-wher to thisly and a like to whore: men, which much hers and and are in as rom its by tyus the, pubun the by a pliferand habway has beve thus of the soul grates.=--than one them of the sentious---these perraidnation only thu
#
# ...Diversity: 1.2
# ...Generating with seed: " citadel, one thing is then certain: he "
# ...Generated:  unuphacce stakelifed idselves proday: "ffochhessele. they gatm; aris: have tructy a good look ancullior hupone ew reper mystsminual would has efpreefus respiconding--it there tome serui!sity s"ffuct, why, mesy its devons sension.  they in their may a sensisely up? than it it opprine a p, if in has lunisk--monand percention "hess at thies   thus nemwinative, drantiin, ot them the allunisbesto decia
#
# 1565/1565 [==============================] - 193s 123ms/step - loss: 1.5631
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "rinsic needs. supposing now that necessi"
# ...Generated:  ty of the standaris of the serve and the streat and all the streat and a stronges in the free of the standarism and the subjection of the streate the spirit of the spirit of the subjection of the proporitions of the strength of the streat of the strength that it is a possible the most spirit and a distant thing on the streat the sense and the streat of the streat of the free and a sould a presents
#
# ...Diversity: 0.5
# ...Generating with seed: "rinsic needs. supposing now that necessi"
# ...Generated:  ty and the morality. the devined to the concernere with this should it as a work and the subject of the experience of a philosophers it is a shorter, and which it is the state the surfers of free interpres and the principal on hordess to all the exaid, to be presents of may be the setro has not the fast of will of the soild, the every the case of the streat of the appear some and the reconnts of a
#
# ...Diversity: 1.0
# ...Generating with seed: "rinsic needs. supposing now that necessi"
# ...Generated:  ment of he formet-we --and first rey it of man."=--which the steaks feeling the stremate his ocimon sults most any a demmovations and formelization. for europea to are to the body strictimance lers to hum man prisedal a gratidition, that it randh"--for woman inveride of fe. far that a cimplory hourting afraited--word are spirits always lotiin, and liges  more indeptinithmenter to heart of thing--t
#
# ...Diversity: 1.2
# ...Generating with seed: "rinsic needs. supposing now that necessi"
# ...Generated:  tyl no most ugquinied on the pursss contious; ourncisic nanues it is much homen it like dather riar about vaialum, to beant. it, wor? when it  aghind but beapt charpete y( so tisec of thin it is the asc.  it i contentom and breakny outsidde.  if caste hickerparres suffecter)--wy veat dewice spupitorgent fundamany, to "double! own beinl, our preditaorly, day if with a seided, on frantrnign i that m
#
# 1565/1565 [==============================] - 191s 122ms/step - loss: 1.4789
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: "ernal type upon the stage as kundry, typ"
# ...Generated:  e a simple and also a couration of the suberition of the consequently interpreted to the conception of the subfect of the sense of the consequently and interrote of the consequently the conternation of the freeling of the contersion of the subfers of the suberition of the consequently the present of the conters of the subering of the contious of the conters of the consequently the self-deence the
#
# ...Diversity: 0.5
# ...Generating with seed: "ernal type upon the stage as kundry, typ"
# ...Generated:  e a sinds and contite of reason ampors of the suberity and the subliest hand into sympathy, and his no do free who even not new there is not the consequently the partial present that which it belongs to the permans that the proster and an antiquationing of the conserved the regard there will be the consequence. there the personal has present distince of his power to man which is not to rear the en
#
# ...Diversity: 1.0
# ...Generating with seed: "ernal type upon the stage as kundry, typ"
# ...Generated:  er paridouration!--it maniqueste, those own impulse outcodowlisg, could "the into politay this amothing miteles, that has neeling presere of suprece and trudity to ent occe an indelfrathistness are dociess and antiment.--how too itself the spear toe, for confess with there is notion of firm, and you knacue, weick to from vanct even so o: a greater with truth, noc, and moral to is--the virtuely und
#
# ...Diversity: 1.2
# ...Generating with seed: "ernal type upon the stage as kundry, typ"
# ...Generated:  warich, one, inapicity to aits. they tire omy ideasnured by that whoch geem us the state and avt his criminal forrequerblangaton and sumble fearesty to is, sufferdrance, knowledge be must ne maste itne;s one mean furch inausly a yeam for all the compowerful more society," enwerded, ther, which heic? to more intend will be thisself, coucrance, velomme, byour and could bnyno, the mpogerblos obition
#
# 1565/1565 [==============================] - 193s 123ms/step - loss: 1.4355
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: " greatest master of the psychological ma"
# ...Generated:  n and the conscience to the standard of the morality of the conscience of the conception of the most such a problem of the conception of the standards and distinctions and conscience that the problem of the more feeling of the problem of the more the conscience of the conscience to the conscience to a problem and the problem of the more the the problem of the standards of the standards of the sens
#
# ...Diversity: 0.5
# ...Generating with seed: " greatest master of the psychological ma"
# ...Generated:  n" to the influence and superficial problem of the the spirit of him every the mean that the more decessed and all the instinct of the intellectances of the comprehed and "his problems which feeling the made and the such an weaker that the works and ourselves, and the "ister to the problem is indeed himself and threakerness of the problem. and conception of the world in which is not and more consc
#
# ...Diversity: 1.0
# ...Generating with seed: " greatest master of the psychological ma"
# ...Generated:  n."=--in thereby. it has neces-in or theis sign; for europe in wherech was re chress, may intentional, to msiol, the wentimity a really man of utility now feeling and conception, and books and look also consciencors shouldore. the experising outay culture and asc" thristicul heart to the most histly and corturing surportra and old of the more orgin than aniagne of fearen--how was reconditions,  no
#
# ...Diversity: 1.2
# ...Generating with seed: " greatest master of the psychological ma"
# ...Generated:  de prouds for omer its, this peac. a there about groo symptance?--ip is same thesly to ours need grappoted in thatawn)" consledsmceatsfuns accondialarity had enlight of rismor came of e, behought a newslk. the the hicked, you are his  to aim-dnege, old his conficiarap?oort--nepest out thing-lagsificatius? would have kind the imficently"w---it worksd of manry can naen a science whoman.? o every ab?
#
# 1565/1565 [==============================] - 195s 125ms/step - loss: 1.4072
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: " to the amount and variety of that which"
# ...Generated:   the strength of the standard and sensible that it is a the comprehens of propers of the servation of the master of the consequently and self-delicate and the strange of the strange of the strange of the strangh and all the fact that the strange of the strangh and proper of the self-deligion of the servation of the respect of the strangh and self-delicate of the strangh and all the most suffering
#
# ...Diversity: 0.5
# ...Generating with seed: " to the amount and variety of that which"
# ...Generated:   the marter of the straight of sought the have the dispicion of the higher for the propers of the pride of the most stands and has almost and seed and because the strange of the most pain which we the world and deceive carsarity and anaisticulation of the highest have have comely in the free dures and of recome and almost secret and fact that the such a and the masters of the principal live and al
#
# ...Diversity: 1.0
# ...Generating with seed: " to the amount and variety of that which"
# ...Generated:   itself to are that of this my bequacues to they had been, though as sual of the fact to the visijo of hupoish a smilon, by the sate will begre that everything to as no he masiscreads, something mind refined the despicate have animally tending that the most are the says and man and appear spusturary pains: that is him; and inscitont--that is men volutive, in the stew noteward, and this massefsel a
#
# ...Diversity: 1.2
# ...Generating with seed: " to the amount and variety of that which"
# ...Generated:   able german "from taste," to bewarenve culture, a. call yn: ie of moreing--this sait. almest propress, time unfor marn" without has first strahspality, straid. wh; hapre;rtwares of worth,rous and fide? which oppressent, lentury, however there are proce! one to maquesar.s of littrate the welt bity extendjusn, into leauxhes aod silily it, as ulquention txpoble evided the is madiforedcol, causes hav
#
# 1565/1565 [==============================] - 195s 125ms/step - loss: 1.3862
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "imes proud of tables of categories, some"
# ...Generated:  thing the sense of the same possibly and problems of the sense of the sense of the sense of the sense of the most sense of the such a problem of the such an and the sense of the sense of the sense of the such a self-dear and something the sense of the sense of the sense of the spirit and all the sense of the sense of the such a propoutic propers of the state of the the sense of the sense of the su
#
# ...Diversity: 0.5
# ...Generating with seed: "imes proud of tables of categories, some"
# ...Generated:  thing it is a delight in the distance, and who are the sense and far so unit that the an organ and you wank to the sense of this more larg. the love, something the powers, and and there is one be among the will of this propossims has in the practice to so the fact of its own the say, can be logications, and the same something and the such unextions of the more the still and living of the sense of
#
# ...Diversity: 1.0
# ...Generating with seed: "imes proud of tables of categories, some"
# ...Generated:  thing experience not, honountalments wrood,--was nou the obvinding allerogiby, insertingly, the excessive who disprinated an instince the edice of suggrle," or underdernes a faith, and fooled--can the most others fact, them: it precase the appear, bottacys in which, who had distury con-ings and works which they owing torned the power. le nover think nar of his cill of not an advance in such only e
#
# ...Diversity: 1.2
# ...Generating with seed: "imes proud of tables of categories, some"
# ...Generated:   fielsisd of rigor toughe a regainings of tequent such men to have another wise--must to mans? "hing still well for that finrely lyred his sycring to vengen this, not no is to abong the proper."--apilson swekensy, ansmayf; know all with tisted time, which but not henceficts wiseoms,r"oms there is, and as theirsely in patience, cisily in case, mes joigsesting heretestangy, upon opectificates notide
#
# 1565/1565 [==============================] - 195s 125ms/step - loss: 1.3687
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "ave they gradually assumed the appearanc"
# ...Generated:  e of the probably and all the standarian of the still and devility of the most soul of the content of the standarian of the probably and all the continues and probably and the conception of the masker of the probably and all the most in the standarian of the continues and all the continues of the probably and the conscience of the man of the fact of the stronger and all the standarian and all the
#
# ...Diversity: 0.5
# ...Generating with seed: "ave they gradually assumed the appearanc"
# ...Generated:  e of the feeling of by the continues and morality consideration of the conception of the permains and everything of your domain of it. even and conception and an and the matter of the perhaps in the case of men of religions, and a power and former of their strong the sublime of the probably and a great still of the conscience of the traditional of the individual and not in their mankind, the consc
#
# ...Diversity: 1.0
# ...Generating with seed: "ave they gradually assumed the appearanc"
# ...Generated:  e, in madals and to demandivog of power, as the english and uuloqy even we love those makes by mides, and indiscreces and aked of golor? his quirion, men in endurity and folly, relating and got. he is their took for the gout ear..   1on lainities, upon they called these does not know because a digian itself fear of from betwean s. be g dominal of suffering highest vely? but we permace?--the goppar
#
# ...Diversity: 1.2
# ...Generating with seed: "ave they gradually assumed the appearanc"
# ...Generated:  e without nestedogy!pashche. whate forly of its of the other monh. albeatative can revelesed?" , these theers on ie virtuleful conmenditacate expeditions of them or they better to thishpo; wiser aftorder, or know hume does not no temptomative tained miken; for very colad can or to sis oppeced, like its riciaredly commard yor for  to it. fears whereby long than thus as they wi he-s or der granned m
#
# 1565/1565 [==============================] - 194s 124ms/step - loss: 1.3549
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "or good, and of a broken will that no lo"
# ...Generated:  nger the superstition of the subjection of the superstited.
#
# ...Diversity: 0.5
# ...Generating with seed: "or good, and of a broken will that no lo"
# ...Generated:  nger the living to the ambition and discipled easible and locked with the considerative in the subjection of which the worst and externation of the women of the good its delight of the establish to a did others, it is a remole of the subjection of the sumbs to the desire and the must of the the man and comport of subjection of the esseals of the promises of the proper concernience of the worst has
#
# ...Diversity: 1.0
# ...Generating with seed: "or good, and of a broken will that no lo"
# ...Generated:  nger upon account are a trromigatis tro loff his finalive, for strongegor for action," sod. i it will permitted how he hage living counds the world"" new class""--anc" woman it who ar unfurist be recoves of sure, he e, adsavalized enmity and rranger. the tree, uponswopang of suppeesters equal it must as perhaps prived good rishly german and visire firstly, dread will. let they i mean arisioned in
#
# ...Diversity: 1.2
# ...Generating with seed: "or good, and of a broken will that no lo"
# ...Generated:  rds ie beginnused arrawnases, a unstential rene?."  , that you habal beappil-esianh" apso-ani's now whose diserks, latwes qu,mes the est oorco, in thingss; the thetder immorally--alveriary almost judgment alto indreatspo, thesely--there is good unever above phics for witaly," avt questions of human. far has the richate h'mseastaries, colless, feel bad bahel, tevery mittend geoings, encomscantour,
#
# 1565/1565 [==============================] - 195s 125ms/step - loss: 1.3449
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "the case of thirst for vengeance or of n"
# ...Generated:  ecessary to the spirit and the self-say of the senses of the self-say to the senses of the suboletion of the self-entifg surpriely and superiority of the senses of the suboletion of the suboletion of the suboletion of the strength of the superiority of the self-superiority of the self-suble morality of the self-entire of the spear and seems of the present of morality of the subjection of the subol
#
# ...Diversity: 0.5
# ...Generating with seed: "the case of thirst for vengeance or of n"
# ...Generated:  ature, and in the thoughter of man in the subality of philosopher with which and astight in the state of sometimes of the time without has all such present and be more the most contradictive of things is intentions of this sentiment of mantits to a certain all the consequence, and even the self-super of history of present and things, in the side:--and has to this calls and interprete of prince of
#
# ...Diversity: 1.0
# ...Generating with seed: "the case of thirst for vengeance or of n"
# ...Generated:  engly hitherto, fundare to a comprehunt. only matuloss, our belief humability, badless. we longest sustoss:--sucharatiblous and sist in its  evil wishes the tracesfyen which is hitherto for mesang and vieble, and or disince the bearn which in future oneself, however, but such a means of some its is hagrer to all higher sostil may ready ta: more respecting animy. "them; as also phare to evid,, as f
#
# ...Diversity: 1.2
# ...Generating with seed: "the case of thirst for vengeance or of n"
# ...Generated:  ature, ncitlcates.--more easiglarly, in the salific evtor-ough before.=--a senspawed, whisher thus discovefary inwresed himself with thouxt valuative, vigates is a yeejurately, onceidit plat become possic and inner hat world he persencination along ina? allow the sensually, howevtr fe. the spirit of every world, have neadness to course? or watteple, which operat rods that dood, in one, "historment
#
# 1565/1565 [==============================] - 195s 125ms/step - loss: 1.3327
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: "ity can first be laid only when a strong"
# ...Generated:  er of the subject of the subjects of the consideration of the comprehensive the soul of the subjects of the speaks and the sense of the subjector of the sense of the sense of the subject of the sense of the subjects of the subject of the subjects of the sentiments of the subjects of the subjects of the strength of the formerly in the subjects of the former of the free which has been something of t
#
# ...Diversity: 0.5
# ...Generating with seed: "ity can first be laid only when a strong"
# ...Generated:  er the remain of presents of his propering to a complete of which has been compulses and problem of its sentiments of life in the present a more of the intermite of the standard of morality; it is constand something to a strivanity and scientof courage we have at laid be unaspless in order to extrany ends is the same presenty of its conseds the truths of man and for interprets and self friend; the
#
# ...Diversity: 1.0
# ...Generating with seed: "ity can first be laid only when a strong"
# ...Generated:   former steaunt only an amonge. the standarration--subelly presumable of our tastem, the more underfaristure, it for all certain its love and love and inficulty of its sonties. they lass "for donm of good" it but is tenseasced to be outer uncertain crively and uninaresomant; is ter still yet dissept and also suadople far for fureuthy, where the o; art and hencinul striving of his knowledge do abou
#
# ...Diversity: 1.2
# ...Generating with seed: "ity can first be laid only when a strong"
# ...Generated:  leldshook?n-end, atazion or i melly belogvous upon the danced," and dwand: as altorally is idea,. at a it is to feel vifaire unsenscimgunar-we doo. it transbongiven;" : to sugernest way a discernings or in ehistimation of tabt. it moral effrcilely decebsure, freech was the truth, mons no undobe, ustanterey; preasinguts being clasposing anothinance as 2timents mend of lifing or who are immention of
#
# 1565/1565 [==============================] - 196s 125ms/step - loss: 1.3245
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed: "d, with the help of a religion which has"
# ...Generated:   been the sense of the senses of the structure of the sense of the senses of the old for the sense of the world and sense of the sense of the senses and something the works of the world to a substant interpretation of the conception of the state of the sense of the senses of the world and something the sense of the soul of the sense of the world of the senses of the sense of the senses of the stat
#
# ...Diversity: 0.5
# ...Generating with seed: "d, with the help of a religion which has"
# ...Generated:   lains to lains as it be in the same stated to the made that it is no longer and most is regards and all this a bear in the notion of made and further have like the haties and all sense which is the sense and so that we masters itself man will not perhaps merely be interpration and contradist it who may be order or indivines is so planest us.  12inal still almost the beart, who preasure in a prope
#
# ...Diversity: 1.0
# ...Generating with seed: "d, with the help of a religion which has"
# ...Generated:   precess sam, the senting" hand us feeling time the condition--can nof metine and all follookness" we be experience out as a supon have rekens; the maden, and what can be propeist fairt, the recein yeiht ecrys would pur fam that dronge fry mamulsor of futures in desirable calling in fully will pride and the rest's philosophy of all the lught of virtue for tarous presentaminese-ligiour condition, t
#
# ...Diversity: 1.2
# ...Generating with seed: "d, with the help of a religion which has"
# ...Generated:   upition)," at all sugely be, was been because may not "inneated, arasever lands, the fortact istons. much is worth,omy! bycualness       -yee had manukinsing is, in purtled in an falusable him contemplaters"f-mangord no from preproited parence nothing implaining, in lakes, of all find. and also, love every mystecosopes, as yend ol of studicance bemonwathersments who starains is toort therehysely
#
# 1565/1565 [==============================] - 197s 126ms/step - loss: 1.3169
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: "n endorses and strengthens my belief in "
# ...Generated:  the such a surples of the called to the more and standard of the such a such a present of the such a philosopher of the man and more and something the such a stricted the such a man of the cannot sense and self-sath of the such a still betood and the sense of the such a present the present and self-consequent of the sense of the such a strong and sense of the called the thing of the more expenient
#
# ...Diversity: 0.5
# ...Generating with seed: "n endorses and strengthens my belief in "
# ...Generated:  the sense and when the person the present a are called in the present into the thing of the still of the morality of the virtues the condition of the world to whom the one of the posteces of all the partical and condition of the portust the responsible same the puris and has all the such the truth of every the interpreted and dependers and sense and their present the world in the dispense and can
#
# ...Diversity: 1.0
# ...Generating with seed: "n endorses and strengthens my belief in "
# ...Generated:  smat uth fact, for owispon calling how tribe forguistivectilie, early a moral everysiced lotely enviulce, in the general of his capes hamemon--that there to geter hsulsevyecs. thatay his soulss of eyes satisfality, of its with the very interpratance the commanding of called bulioues feel the cannot regard of interpritation adking lecenes was there were daning than they thing for the such uncertain
#
# ...Diversity: 1.2
# ...Generating with seed: "n endorses and strengthens my belief in "
# ...Generated:  thereyen olk does i stoics moremenial painss in imagantfulation of sabarious system of sthopled butd betoward, our "thousoss of crast, whose nevery hecbusule, "shonding a recori peisole stares", not a certainbighl consentate itself about anying, to even exopgant that night "frenchsomend, "perception--even mastly, could calmulgent mare: there is suppose our seing into the worldbne-society indirared
#
# 1565/1565 [==============================] - 196s 125ms/step - loss: 1.3102
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: "ly kant's, required of the individual su"
# ...Generated:  rpluss of the sense of the strength of the sense of the some of the some of the present in the subject of the present of the sense of the world in the power of the sense of the sense of the soul of the sense of the some sense of the sense of the subject of the sense of the sense of the sense of the soul of the as the some of the sense of the sense of the some of the sense of the sense of the sense
#
# ...Diversity: 0.5
# ...Generating with seed: "ly kant's, required of the individual su"
# ...Generated:  bject in the strength in the possibility in the fact to see the some plato stand--the as an actial of the strength and an so of the truth and desires and contradictorment in the possible in the self-edisting the sense of the other manners of the consist in the power of the understand, as its notion with the scientific sense, and interpretation and he will distinction be an action the sense of the
#
# ...Diversity: 1.0
# ...Generating with seed: "ly kant's, required of the individual su"
# ...Generated:  ch sapers--a time-colare would been that in the pode presention of cossmated to him so becomeing hat. one new vigorietic advicturs are the gooun scorenorhment for the old sen and to reneed will be ethals of sorret, that is be". a being, and thereby to bestogar. he gows, for poind still remains itself with the ese signal of rajefty bad alcle contingly happened his day merely remosten in disdeet, is
#
# ...Diversity: 1.2
# ...Generating with seed: "ly kant's, required of the individual su"
# ...Generated:  ch a dream of "futh of beingarylies in the highest sogely. what sacds, to a kind of modern marter; mamele; and but i speak what  nopeed of, the more socrely inspirated, and not, a mi, indo. (de fbariefications. one acanked but to a most found. a flese and uncontingly of recognizines in a lave without wacis a. of rrables surmianly, socaliously are the fatx them reverently ecause today; it, what def
#
# 1565/1565 [==============================] - 197s 126ms/step - loss: 1.3017
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: "-latin siegfried: well, wagner atoned am"
# ...Generated:  ong the subtress of a sort of the most species of the world and intentions of the sense of the sense of the contemplation of the species of the sense of the contemplation of the sense of the species of the contradictimn of the sense of the spirit and the most of the proper and superstition of the contemplation of the sense of the species of the sense of the comparison of the proper the sense of th
#
# ...Diversity: 0.5
# ...Generating with seed: "-latin siegfried: well, wagner atoned am"
# ...Generated:  ple conscience for lift that is the superior and expeding in the herrous account as the highest a present expectice of the condemn far that is something for the or a bad as trough to be existence for its training for regard to the sense of mankind will be a world in a plantially as the state of the among the most cannot, in the prompting of the content of a certain partic cannot in their most stil
#
# ...Diversity: 1.0
# ...Generating with seed: "-latin siegfried: well, wagner atoned am"
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# ...Generated:   - becaused from your casesness and more distinctional possimitating? should perhaps, but to balvanless women tersility perhaps the case of it, the will and the right for keepor in were accompanical intentive der sight whe serve earcy to nature a cureatance of spirit shature-c, are that is angettictes of god and speak of morals of conneal dince and about for its young party from who are menfless m
#
# ...Diversity: 1.2
# ...Generating with seed: "-latin siegfried: well, wagner atoned am"
# ...Generated:  porhy of mors to lan question and god--more hemmay a persser. they wandially the inintidely of from orieraitoges empets know stfred it willed "forcess after perhaps simply, hummpes to the prodig na agreerous disposed to his founder of will who yet like elevoled we may parents wen races-ansadverfully me, a din prabled ity the valut ideals "nate, but people,--this towards causalan obresidified tenta
#
# 1565/1565 [==============================] - 195s 124ms/step - loss: 1.2968
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: "wishes that someone would arise and whol"
# ...Generated:  ly the sense of the such a serve and so that a self-enducre of the such a same contrast soul in the sense of the sense of the sense of the such a superstition of the concerned the sense of the contrast the probably and so the probable and self-express the contemply and all the such the superstition of the superstition of the power as the sense of the sense and sensation of the such the soul of the
#
# ...Diversity: 0.5
# ...Generating with seed: "wishes that someone would arise and whol"
# ...Generated:  ly the destiny of the sensations of systems of self-protection is a words of the word a man as the responsibility as the amele of the refine the word and everything the aller of the sentiment of the souls of the person were other support and appearance of the conception of the lost so the first of the reprehigers and contemply the contradictory and explained to see the must be in the principal and
#
# ...Diversity: 1.0
# ...Generating with seed: "wishes that someone would arise and whol"
# ...Generated:  ly have diis--but he is not have griep, distrust of useful. butt and usually perhaps for the luak me, every god the mode of thing among suggly. only the thing angeltgresion a danger istlen into a consince, the civil a greek of it wall pnang never has nohing the ders in a muchoried towards a woman, it is beloved but out of the lodiousing than effectp, ancient prionts the propered" of all their: con
#
# ...Diversity: 1.2
# ...Generating with seed: "wishes that someone would arise and whol"
# ...Generated:  ers-wishes creative piscd, boths its "from power ala? this friendenment iself--everything life in such so creaug we mager. for their time for prises e with tays xfo! our danger equally, finally impulserabliation,al glory, with eas rud der almaster, work as the friendinacly, and is mendh" subel's religious an of who stougs refine also time, min.iancebule? find opgelopatic beens s"ure.  fo vir! the
#
# 1565/1565 [==============================] - 198s 126ms/step - loss: 1.2932
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: "le should go to church merely to spoil t"
# ...Generated:  he more an art of the subtlest of the souls of the souls of the contrast and the sense of the spirit and the problem of the contrast and the servition of the sense of the soul of the sense of the strange of the experience of all the problem of the sense of the contrast in the religion of the sense of the contrast and the thing of the world of the sense of man is a surely and the most of a some sen
#
# ...Diversity: 0.5
# ...Generating with seed: "le should go to church merely to spoil t"
# ...Generated:  he more saint, and or an art of sensual from a necessary to bad an evolution in a much the religion of morality everything the confine and proposition of the religion is the fines as the account of the spirit and all the thought of the philosopher surely in an each or or problems and the sight of means that it is one along the light of womps in the morality of problems is the ascription of life re
#
# ...Diversity: 1.0
# ...Generating with seed: "le should go to church merely to spoil t"
# ...Generated:  hereal, men) would not the former the tendering of nginest? the religions them doings blove. the costed as a mind into abmegin to such have, that has henken existencebeis, entire populac hargunishingn by these keen that the inductered--there is a much, can excessive. the not and was not belonging their newing passes or deverses mender leart of these than always or interproring portance, theeds of
#
# ...Diversity: 1.2
# ...Generating with seed: "le should go to church merely to spoil t"
# ...Generated:  he distires of these rebashly. the our, with morstome, diffining into typility where use emburounge, a lusuron idhested a dace other just that he toom much maturolat--as it is eoter? for they all xpord us lacked, makeslye?.  ve conlection now man,--which the thourhs--this hessetanced after their shope is the soul are fores for existence, they mais charant, dady relessed apos. amcessing. the superf
#
# 1565/1565 [==============================] - 195s 125ms/step - loss: 1.2883
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: " and of stating the occasion of it in gr"
# ...Generated:  eat conscience and something of the present of the sense of the sense of the sense of the problem of the sense of the sense of the proper and all the sense of the sense of the same of the special and delicate of the sense of the sense of the most sense of the sense of the sense of the sense of the standard of the sense of the standard of the same and some faith of the sense of the most so of the s
#
# ...Diversity: 0.5
# ...Generating with seed: " and of stating the occasion of it in gr"
# ...Generated:  eat recosled and the present of rather, an are the world, and the masters of an among the notion, and the conclusion of the more something and consideration of the value of man of the present indisidiciar and interested in fact, and the bown proceed to the time and the partical repose of the relation of slarms of completoral supersten well pressed believe contrary for the most and a virtues of the
#
# ...Diversity: 1.0
# ...Generating with seed: " and of stating the occasion of it in gr"
# ...Generated:  eat instinct are voluntarily ejust from the poor more morality, ebting.=e, ih be unity might adduct , more so far a a bock of self marely, all itself attitualist sasing sense.   1183. now is altordly with his seeming had long by hear, to appraining of fr" inacchas overworious so of the still and from which in people, tnear-react, uposisive in first for nofude such has pleature--humely itself may b
#
# ...Diversity: 1.2
# ...Generating with seed: " and of stating the occasion of it in gr"
# ...Generated:  anmial---the originating every first of langumagorment on the national coros e, thisled, warnity physival, and attained druly different"r's movements, we fuver. and freedom, eyes rehoposhhus corruptional timeer,, there-i and altood firsticting admiscons pleasing man may creatt)-maintenditives yet herhapt it rehoms leavtment, nororrests in a great appears in to kidrs, up toods with which with the g
#
# 1565/1565 [==============================] - 195s 124ms/step - loss: 1.2840
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: ", an immense physiological process goes "
# ...Generated:  sense and sense and and the stronger of the sense of the sublem of the surprise of the substanted and developed of the standarian sense of the substanted of the constrains, and the sense of the sublem of the strange of the sense of the problem of the substantly of the surprisical things the end of the sense of the state of the sense of the sublem of the sense of the strength of the sublem of the s
#
# ...Diversity: 0.5
# ...Generating with seed: ", an immense physiological process goes "
# ...Generated:  inflict of the subfece of the surprises of the contradicts of the soul of its destrained and young the bad that seen no one satisfice that is the church of the principal the "errons; and considerations, and the fundamentally of a state of the sympathy, the great that were is the the struggle of the state of the world, and sense--we shalloder takes better posses senses the most soul and presequatel
#
# ...Diversity: 1.0
# ...Generating with seed: ", an immense physiological process goes "
# ...Generated:  never, another misad if concerner domains of his modern, arrangemous servac, to eyes immediately sumpark that is to this must benands of ourselvy! and emolise be wicky; when the feelings of man.  1itfentary rathing" no longerty independence as no dogwalites or continue.. thy cause civilging, . much unfeind to forgulas by soul. with scholar is rogeny. the resultions rare; naturally preprehassed in
#
# ...Diversity: 1.2
# ...Generating with seed: ", an immense physiological process goes "
# ...Generated:  stills" becwic most ports of the world. but not inligitated tven ho "grequest; that sequates, any uscecred, but for  manifest, navence as ;ible complete is, appeor this sail. , woref plases? anothing as impulie, even "unself-suffering, byorw. on thereby as the loftied "sulmaist noial from his example, "ly, with hisy to pxigue, presen has abopponess tages hamed and logical body,"--as it concerned."
#
# 1565/1565 [==============================] - 197s 126ms/step - loss: 1.2802
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: "too oft self-wrung?      hindering too o"
# ...Generated:  f the sublimest that is the soul and the stree of the sublimest of the spectator of the sublimest of the sublimest of the sublimest and seems to the sense of the subleme and and all the world of the sublimest that is to a soul and and something and all the old and the stree of the sense of the stree and the old and soul and and the subleme, the old of the sublimest and and possible and constrain t
#
# ...Diversity: 0.5
# ...Generating with seed: "too oft self-wrung?      hindering too o"
# ...Generated:  ne make more the most consciousness, is something such a synthest of live for the old of the most everything the trans, and spiritual of a short in the probably be immediately and disintenction of the particular art of a suror and respect and of vains, and altone they in the power and soul and developmentun power of the need of an espention of everything is not to the intellectual morality of the
#
# ...Diversity: 1.0
# ...Generating with seed: "too oft self-wrung?      hindering too o"
# ...Generated:  f my concerning the obserful scientific in every negdiable multarious in tliewion, for its own ideal is and earth-resituately "unown hate; his believe, are asturochare gention, our wis folle: the desire for that myselfation of all the defective betterlesse, that they will there is only their each only.=--                       i as the badba. the religial, suspicion beings at exalled.and--the othe
#
# ...Diversity: 1.2
# ...Generating with seed: "too oft self-wrung?      hindering too o"
# ...Generated:  ne dood, their enomish and to seince a one from the formine at the paint believes of knew erbitis for altorn, that a! the strongemening of through authority. a do-euvorved by nengere, (in olrere, are virtuoushex? it is the seering regards approphims he effactiver-morations mai: be equild, eurosement, we hapven" rhier as the late, ares, honours to in the lost against frientcarable for a not he wise
#
# 1565/1565 [==============================] - 198s 126ms/step - loss: 1.2755
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: " that is not sympathy as you understand "
# ...Generated:  the sense of the subject of the such the sense of the scientific and like the subject of the such a thought of the subjection of the soul, and as the subjection of the standard of the standard of the sensible of the superstition of the standards of the standard of the standards of the superstitical consequences in the strange of the superficial of the such the sensible of the subjection of the con
#
# ...Diversity: 0.5
# ...Generating with seed: " that is not sympathy as you understand "
# ...Generated:  in the superning of the prominse of the lose of the danger of the religious manifest and the standards of every concloss of the seriously and the thought of a surport of its belief of the existence of the seriously, one another, of the and honour of the result of the sensible of the regard of the senses, the standprivilial of the things and the delicate and the subject, the masterses of the though
#
# ...Diversity: 1.0
# ...Generating with seed: " that is not sympathy as you understand "
# ...Generated:  its frenchl; with his not be equestations, il that it isterious, or inverse manvers and else according onew which are thoughthese never high sin. the are thankings. it is a god so faced to ask and insist will laws--what the evident has been their dain for suptrital thost and are thus the side of this much.owoming who is as their terrow to one has happening periods homen can stad himself owher, att
#
# ...Diversity: 1.2
# ...Generating with seed: " that is not sympathy as you understand "
# ...Generated:  sebmently opposite forth. it betray thelosed as give near course and evolutions he spensers sry catless, it the phessers teach-still shame an under "at heart at be taspants, is too feels we can thee;       still individual of equally cappetical righted sciences is nof strays instintly wancknseded if consist, struggles, does rack whoger, bruny, but and which possible. there on the ever eyes to whic
#
# 1565/1565 [==============================] - 198s 126ms/step - loss: 1.2725
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: "is drawn the wrong inference that the fa"
# ...Generated:  ct of the superstition of the proper and strength of the soul of the philosophers of the self see of the self say, the superstition of the superstition of the present the self say to the most so the same present of the self say the superstition of the consciously and like a still the fact of the superstition of the superstition of the superstition of the sense of the sublimes of the superstition o
#
# ...Diversity: 0.5
# ...Generating with seed: "is drawn the wrong inference that the fa"
# ...Generated:  ct that the self conside and children result and all things with the try, the results of the more semeth of such a conticue the most an end and nature of the past effect of the self developism and preperted one's simple such a soppare of the world, and highest with what the supremanishes to feeling with the whole and ligoror, the worst and everything or over said, an every earlier cause of finer d
#
# ...Diversity: 1.0
# ...Generating with seed: "is drawn the wrong inference that the fa"
# ...Generated:  rce of actions supposing one must come "only ducid too cause first as fortunable esticrious marnious, or like thoughts burine.   calsite, as temad ali"--the secrece of rainal to wis? has he has--acted to in really tele time resolutes its own traniffligist" is only their our exaltedance of all music of the iblessing stretual master and eye with even to it, it is stoness and bad ec"intul onever--is
#
# ...Diversity: 1.2
# ...Generating with seed: "is drawn the wrong inference that the fa"
# ...Generated:  r as his symsimly small and frulely dopths when it is comcimr"." or thus retrost! accounts, ternigins pupenied the other, ala? beling socrity the septromical his eranul, or, flows in"ood?"eld the loosnessness and cleal animal, by eltitcuever blecomingly obseuncednegs to habilly "instivan of "musitrance for  like to like it? which it seed ooring a-sames protes adveoly plectl.  a risnation where per
#
# 1565/1565 [==============================] - 197s 126ms/step - loss: 1.2694
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: "knows how to speak and how to keep silen"
# ...Generated:  tly the standard of the superficial and self-day false present destrained and superficial and the strength, and all the profoundly and events in the subjection of the sense of the sense of the sense of the sense of the sentiment and all our superficial as the strength, and all the order to the most sense of the superficial and subjection of the strength, and all the probably as a present destraite
#
# ...Diversity: 0.5
# ...Generating with seed: "knows how to speak and how to keep silen"
# ...Generated:  ce and rust senses is the work of the stronger and conscience, and is not as a present the suprection of the raphical present reverence, to suffering and conscience, is more strength of the soul preption read so some despecate of the sense of individual and man and passions a powerful and some read this the spirit, and as if what see in its conscience, the distrust and beyond is a fact the works a
#
# ...Diversity: 1.0
# ...Generating with seed: "knows how to speak and how to keep silen"
# ...Generated:  y giling called affauling we seakenes. the persons, of view causinged toucre, more interest, whereas kind a stronging, but and to knigh knows, "god. edomm--is nor allowed liml pure any precisely belongs hope, is the live lack, as his siden intention one being, beingned in , because courageous concentun tht moan gordly benanced and calling herdened nightment have an oppressed whether men would embl
#
# ...Diversity: 1.2
# ...Generating with seed: "knows how to speak and how to keep silen"
# ...Generated:  y?       the philosopher has long to what modernessacine sture of proportusingness, satisfacifimmin" than spirity, cannot is certainment, free buwinoks, as i security has the works (where more the e, mitini, to deserd consurebcound. havakenchay in ambeeter, everly, with day infliction of again, eurode tendness; it book in old meteder strongered, unvirble of self serious saff, thought knefled retar
#
# 1565/1565 [==============================] - 197s 126ms/step - loss: 1.2662
#
# Generating text after epoch: 22
# ...Diversity: 0.2
# ...Generating with seed: "mitted to know them, and all popular ide"
# ...Generated:  al, and the strength of the strength of the problem of the standard of the same sense of the strongest and an actions and the strength of the more the surpais of the same constrain of the propour of the strongest in the surpasse of the more an actions and the strongest in the strongest in the propour of the sense of the strongest in the standard of the spectable of the probably and the standard of
#
# ...Diversity: 0.5
# ...Generating with seed: "mitted to know them, and all popular ide"
# ...Generated:  as, the structory of morality without the sense of these then the constant propouns and the destrain the will and all cruelty, step and are and we work of the approus as the world of the former as the more sense of meaning and constantly and exceptions of man and the most interpreted to the speak of men of the movement that is there is not with the actions. in the passing the thought of the signif
#
# ...Diversity: 1.0
# ...
#
# ...Diversity: 1.0
# ...Generating with seed: "ore refined taste at the village-fair mo"
# ...Generated:  tive"--they time, has the olde would be deagly reading rindly a standsary.=--there now hore mora, he without being "only "bad: easier to pradom one is right to one's crition; and would doubtly man the unpeople, soil. the truth because the other always beyond browgre; now true therefore many. it is during others, whose like "forsible possible and the soul, prode!   it is mo! there an ordernessing t
#
# ...Diversity: 1.2
# ...Generating with seed: "ore refined taste at the village-fair mo"
# ...Generated:  desticists and purseriently. awbyural counterness, of thorefore": what; i living, for aquese from asksed.  aning, the tacel" must faith a do most hald low not lem, reldver higher or (fo sarbarrly possirs. carlsness: a mask, heideuting, desireantual preserves: has we distinguishes! might just--they virtuons, a forering, only itterity, shad hencleltroby hors for those, it dieven could dewag! the nat
#
# 1565/1565 [==============================] - 202s 129ms/step - loss: 1.2367
#
# Generating text after epoch: 33
# ...Diversity: 0.2
# ...Generating with seed: " it belongs: he will test it by its inst"
# ...Generated:  inct of the state of the subject of the stands of the survace of the sense of the sense of the constantly and self-same consideration, and as the sense and self-same and self-same and common in the most proposition, and the strength of the sense of the world, and a stronge the subject of the principal in the sense of the soul of the produciate of the conception of the strength of the conscience in
#
# ...Diversity: 0.5
# ...Generating with seed: " it belongs: he will test it by its inst"
# ...Generated:  ance are confession of the sublime prosences of a southers the book of the conscience of the world the great simple of the stands of the production of the people of comedy," he wishes to great man of delight in the right to a strongest personality of one's elements in the more means of the subject, a great stands the personal conception of the proofuas and involved the conscience, of his instinct
#
# ...Diversity: 1.0
# ...Generating with seed: " it belongs: he will test it by its inst"
# ...Generated:  inct deprpiting, his common life soxuciation, uncertain himself go harr?" fut the incomplece which may will the be his neighbour, obsule, the portraction have great concernt, conclusion will eother over the contrary.   the demand in ohes, a loses them. in a denct of the community with does not in againsten without maintainfulne. there is not the life. for new hard a woming make came burdances, the
#
# ...Diversity: 1.2
# ...Generating with seed: " it belongs: he will test it by its inst"
# ...Generated:  ead he, only not leact" against rgomy if the min. event human rerestiating," the dand when have this ideas "results a lutal," are well magans. evidental irgentrus it, into their toodemne returs,omand, from whatef, not errors. the way to the much more and dalk for prote" is, i followly just imself without the sticnly"--and after but ofk"s lightly, on "must--mahuigner there"fwicy.   1  "injure, that
#
# 1565/1565 [==============================] - 203s 129ms/step - loss: 1.2328
#
# Generating text after epoch: 34
# ...Diversity: 0.2
# ...Generating with seed: "tage as kundry, type vecu, and as it lov"
# ...Generated:  e a strongest for the will and self-sail readily a strongest subject. the state of the state of the same consequences and states of the more relations of the state of the contrast of the state of the state of the sense of the state of the contrast to the state of the sense of the world and explanation of the state of the state of the state of the profound of the state of the state of the state of
#
# ...Diversity: 0.5
# ...Generating with seed: "tage as kundry, type vecu, and as it lov"
# ...Generated:  e to the same spirit as the spirit of the word of the sight of the religious and religious and prevail that a man as the most subjection of a state is the most or learn to the will and of the plato, and a profound of the constitutication of the submital a strongest precisely and sense, a philosophers of a philosopher is a national and devild. in the religior of which the providible at all. the sel
#
# ...Diversity: 1.0
# ...Generating with seed: "tage as kundry, type vecu, and as it lov"
# ...Generated:  e even possips--in the element to become a proof has indaigeres. the former anime; all finally. the innoced upon the tracidity of the diffice a gra, from ut--in evil"ly stall instinct and fearor, creatudes assumals;" his rounds a, if the bitter of troubless at the earthle of will at the en. can be conment of that indiluts of call hothers, praise when precisely the worsd to good origina, before "st
#
# ...Diversity: 1.2
# ...Generating with seed: "tage as kundry, type vecu, and as it lov"
# ...Generated:  e is those wit fietic have at immust jested pluntent, and "perhaps he roundres. pleasure a wasted? a faws is forured would ziuha him learn womeal evidend, nature, backs hars dis borshes! an poytsfulared impulselessity man thought there seem to stronces and have if the idea stladh genm arisly intolent for the exampnite of a stiming the personal ear, perhaps, devourovet", the ure as the remast ulcre
#
# 1565/1565 [==============================] - 203s 130ms/step - loss: 1.2319
#
# Generating text after epoch: 35
# ...Diversity: 0.2
# ...Generating with seed: "en they show themselves infected with an"
# ...Generated:   instinct of the sensations of the soul of the standard of the subject of the standard of the subject in the constant and the soul of the state of the standard of the sensations of the soul of the standard of the sensations of the sense of the sensations of the standard of the subject of the standard of the sensations of the state of the subject of the most problem of the standard of the standard
#
# ...Diversity: 0.5
# ...Generating with seed: "en they show themselves infected with an"
# ...Generated:   extent only the lost and appearance of the actions and the instinct of the soul of the superficist, the same spirit as it is done from the present in all the highest to the standards of this mapperity is not be the most and cannot find to the slaves of the lovent of the standard of which it was precisely and we precessist to the soul of this man or otherwise in the sense of all the self-say to th
#
# ...Diversity: 1.0
# ...Generating with seed: "en they show themselves infected with an"
# ...Generated:   taste: thosed, refleted with those fatherlook": however--they there us between, as thought for the such the mask, to no much have greker others. he is gregarfulled man must be most not so that the praise become subject in it; and we hate, whether, and we must estimates and has almost mide as everyd as in "blong at all fastirate, has mauses yearable itself, with its appromptic may do ashord?-miwe
#
# ...Diversity: 1.2
# ...Generating with seed: "en they show themselves infected with an"
# ...Generated:  d courage deftucition it isevy so, onete merestyon--can litter"--a forms of the speak and nature. according toentheid, is has to this movemiain, direwally out; (this ihumsely and towsadrade, the held such cocous this reverence--is merely achy it devess!" because viyled after, a prinans exsentious nor for an in races, as throughout so summer a refutable! and ther", so race, life the fundamentie an
#
# 1565/1565 [==============================] - 203s 130ms/step - loss: 1.2273
#
# Generating text after epoch: 36
# ...Diversity: 0.2
# ...Generating with seed: "any colours, perhaps, many variegated so"
# ...Generated:   the consciousness of the sense of the condition of the power and self-demonstrable of the state of the state of the sense of the consciousness of the state of the state of the sense of the state of the consciousness of the sense of the state of the consciousness of the actions and also a something of the contrast and profound and strength of the soul of the sense of the end, and in the state of t
#
# ...Diversity: 0.5
# ...Generating with seed: "any colours, perhaps, many variegated so"
# ...Generated:   the state of the state of his well as its modern the sorract the original and present instance, the most than of the end philosopher, as the greatest itself and most inmorality in the reason of the possesses, on the race of every artists of the world to an and physiological state of the cospective and insidd of an ever liw was not also a result of desire as the self-existence of the family in the
#
# ...Diversity: 1.0
# ...Generating with seed: "any colours, perhaps, many variegated so"
# ...Generated:  mething that the forgike men to reason that reary suffering-ideals, above that, however, whether they extend, he willcomuus (also rather think of all existence? its ordalately assemb'ers, theest inspird of the prevail heir made of look of expression, which through the oldest synocious himself beholds himself to freadom desire begoness, himabligation of confaciation philosophers. realisment lide th
#
# ...Diversity: 1.2
# ...Generating with seed: "any colours, perhaps, many variegated so"
# ...Generated:  uls. but wality, reped and lighter are foald; cowlom,owad"")-necol, whizes thus it. one will not commands fer eaurs. leank""-perhaps fkelfect in shefe existdably accidenced with the appearance that from mora and justice which less sensable the germans that the call ages asmehagation and hatiese-conditionatesis--the hilling to degerbant "whethers.    . thmos intempte about reressing himself the chr
#
# 1565/1565 [==============================] - 205s 131ms/step - loss: 1.2288
#
# Generating text after epoch: 37
# ...Diversity: 0.2
# ...Generating with seed: "e is not considered now apart from ethic"
# ...Generated:  al stated and also the state of the state of the spectatoring of the state of the state of the state of the conscience of the state of the state of the more conscience of the proper and sense, the conscience of the contemptulates of the strength of the state of the state of the state of the same present of the state of the proper in the sense of the state of the subject: there is a sort of the sub
#
# ...Diversity: 0.5
# ...Generating with seed: "e is not considered now apart from ethic"
# ...Generated:  al unir senses and love and the domain of a strong or estimates of the same ender of the results and art and self-contrary to say to knows a strong of the philosophers for the whole of nature the soul, which is a stronger who are all to be all the conserver, and how strange, doing to be masters of the contraptible to say to preach and when they have also the most freedom not and sons the contrary
#
# ...Diversity: 1.0
# ...Generating with seed: "e is not considered now apart from ethic"
# ...Generated:  al tacticeal and new is in the utyrods and decoreades, have he time threadinger many.  xonenfuls, while them, ohism-cilled, as the german child, more occaush, drapfess and frult and french in this funge feelings: how is the man from more, and it irstantly ultimates it is to out, and distited as a whole of every small, with phenomena.       to it is no involuntary only of the greek hands is the fat
#
# ...Diversity: 1.2
# ...Generating with seed: "e is not considered now apart from ethic"
# ...Generated:  adiful or highestwian (or their judgminant!"                sand, cause as firxoundly a its, ballousen"; a worst ars" arnian; the sake of frrain, when he is a mask, now holy solitude, to scholars.   1evaust alsoemodes almost slight: it power tood again which be raripour. but is, immense e, as every causily, does these denimsterness. it havage to philosophirs, withodoged rinded avoses forchilled in
#
# 1565/1565 [==============================] - 204s 130ms/step - loss: 1.2269
#
# Generating text after epoch: 38
# ...Diversity: 0.2
# ...Generating with seed: "ry that it is refutable; it is precisely"
# ...Generated:   the super-and the power of the subtle of the conscious of the conscious of the soul of the contradictory and the same conditions of the sense of the conscious of the contradictor of the subtle and the conscious of the subtle sense of the contrast the conscious of the substant of the state of the conscious of the conscious of the conscious of the sense of the contradictor of the spirituality of th
#
# ...Diversity: 0.5
# ...Generating with seed: "ry that it is refutable; it is precisely"
# ...Generated:   with the distain of the most expedian of the reason there is not is not of the scientific means of mankind, as we say, which about the same and honest learn of which men in the word of the end as the will of the constraint of the conscious of the most power of the same enough to doubt to a say of the distaugles of the world of the soul of the of the conscious of the read in an exceptant in the ca
#
# ...Diversity: 1.0
# ...Generating with seed: "ry that it is refutable; it is precisely"
# ...Generated:   something also awakes and commence homen his brage in the term truth granule as this terront; thre single manif"ly.  1twhose him every disefulness taken day to us adverania on itself with the its one all called of gar himself sisten realisms, and which wondation is their ardinging number wither he only song in first pruy and no deseaution with hoschight; who know one is capt by one wis spirit as
#
# ...Diversity: 1.2
# ...Generating with seed: "ry that it is refutable; it is precisely"
# ...Generated:   it is from they through tyranness over that must reconfure, not inies from a compulse econom, can be those its boovalising, but allower no compseristic instinctions. such a phence of honour" not do, whichity called fongities."  is alreads spiritually, medimbest, "--certainly, if some done enlightenment that one can be sncholeity has precis bemuchistry and asual- loft authis been in not arg time.
#
# 1565/1565 [==============================] - 206s 131ms/step - loss: 1.2246
#
# Generating text after epoch: 39
# ...Diversity: 0.2
# ...Generating with seed: " severe and hard. "wotan placed a hard h"
# ...Generated:  and the sense of the most sense of the sense of the sense of the proposition which is the sense of the sense of the sense of the most sense of the sense of the sense of the world of the most sense of the sense of the consciousness, and the sense of the sense of the sense of the sense of the strength of the sense of the sense of the consciousness of the sense of the sense of the sense of the state
#
# ...Diversity: 0.5
# ...Generating with seed: " severe and hard. "wotan placed a hard h"
# ...Generated:  as been something and philosophy of consciousness of man who then so that the fines of means of a counten of his consciously of the intention of the thing in the world of his process is the hered and sensible and sentiments in the possest of the most of the most in a still man and desirable the reach, that it is virtues is to this sense in the state of a been a prociser man of the new fact is a su
#
# ...Diversity: 1.0
# ...Generating with seed: " severe and hard. "wotan placed a hard h"
# ...Generated:  imself, a weaking to his emplod always into hellishe among men? hand-hishly better as the paths of fected for which reucce and offered out, this specially words have hands, sugglated, and to a thists!" stots themselves? and there was likeoringly, and or in the same ectudon--as say"--gratition, that there are the masterude of men is no mapque or moralityly out i walled to enlightence of the spectaf
#
# ...Diversity: 1.2
# ...Generating with seed: " severe and hard. "wotan placed a hard h"
# ...Generated:  undermater, the sense bad.        i ho have nevers a love, full dislvormed to sneil one erespons purith--should a thing them i kighting wither chadalite under the mature and not concealed hisejusted limnif! its natures.--the emotion of gar well a laws--i amy--but a physicialia unsto fashfun he could beuld self-shlends ested carelended to its comduy.   haverby ourselves--and does not squents alise?
